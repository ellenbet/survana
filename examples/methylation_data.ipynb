# %%
import pandas as pd
from pathlib import Path

data: pd.DataFrame = pd.read_csv("../data/all_norm_meth.tsv", sep = "\t")

# %%
print(data.shape)
data.head()
# Out:
# (201082, 1513)
#   chrom   start     end   MB_0006   MB_0028   MB_0046   MB_0050   MB_0053  \
# 0  chr1  762469  763020 -0.007616 -0.008439 -0.009758 -0.006090       NaN
# 1  chr1  762676  763227 -0.014362 -0.046909  0.163637 -0.013934 -0.047771
# 2  chr1  860619  861170 -0.034982 -0.067486  0.031477 -0.003085  0.058204
# 3  chr1  895465  896016 -0.045531 -0.013328  0.014632 -0.029143 -0.041257
# 4  chr1  901375  901926 -0.001599  0.035108 -0.023514 -0.006046 -0.016678
#
#     MB_0054   MB_0064  ...   MB_1122   MB_1124   MB_1125   MB_1126   MB_1127  \
# 0 -0.010800  0.013824  ... -0.003041  0.041990 -0.003041 -0.003041 -0.003041
# 1  0.055077  0.104244  ... -0.012222 -0.002520 -0.000206 -0.009210 -0.010298
# 2 -0.002362 -0.015779  ... -0.000634  0.006543  0.002581 -0.007793 -0.007793
# 3 -0.009222 -0.026849  ... -0.009903 -0.006606  0.017756  0.006988 -0.001334
# 4  0.041221 -0.008694  ...  0.017819  0.009874  0.025737  0.027460 -0.017209
#
# ...
